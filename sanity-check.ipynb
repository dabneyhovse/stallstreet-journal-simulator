# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# Define wall boundaries as planes
walls = {
    "Stall Door": {
        "vertices": [
            [-0.24, 0.28, 0.55], [0.24, 0.28, 0.55], [0.24, 1.29, 0.55], [-0.24, 1.29, 0.55],  # Near
            [-0.24, 0.28, 0.69], [0.24, 0.28, 0.69], [0.24, 1.29, 0.69], [-0.24, 1.29, 0.69]   # Far
        ]
    },
    "Left Wall": {
        "vertices": [
            [0.217, 0.28, -0.52], [0.32, 0.28, -0.52], [0.32, 1.29, -0.52], [0.217, 1.29, -0.52],  # Near
            [0.217, 0.28, 0.62], [0.32, 0.28, 0.62], [0.32, 1.29, 0.62], [0.217, 1.29, 0.62]     # Far
        ]
    },
    "Right Wall": {
        "vertices": [
            [-0.34, 0.28, -0.52], [-0.24, 0.28, -0.52], [-0.24, 1.29, -0.52], [-0.34, 1.29, -0.52],  # Near
            [-0.34, 0.28, 0.62], [-0.24, 0.28, 0.62], [-0.24, 1.29, 0.62], [-0.34, 1.29, 0.62]     # Far
        ]
    },
    "Back Wall": {
        "vertices": [
            [-0.3, 0.83, -0.6], [0.28, 0.83, -0.6], [0.28, 1.34, -0.6], [-0.3, 1.34, -0.6],  # Bottom
            [-0.3, 0.83, -0.46], [0.28, 0.83, -0.46], [0.28, 1.34, -0.46], [-0.3, 1.34, -0.46]  # Top
        ]
    }
}

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the walls
for wall, data in walls.items():
    vertices = data["vertices"]
    # Create the sides of the wall (front and back faces)
    front_face = [vertices[i] for i in [0, 1, 2, 3]]
    back_face = [vertices[i] for i in [4, 5, 6, 7]]
    ax.add_collection3d(Poly3DCollection([front_face, back_face], alpha=0.1, linewidths=1, edgecolors='r'))

    # Create the edges between front and back faces
    # for i in range(4):
    #     ax.plot([vertices[i][0], vertices[i+4][0]],
    #             [vertices[i][1], vertices[i+4][1]],
    #             [vertices[i][2], vertices[i+4][2]], color='r')

# Set labels
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')

# Set the viewing angle
ax.view_init(30, 30)

# Show the plot
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
